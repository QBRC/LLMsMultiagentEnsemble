# %%
# %run setup.py    
from ensemble_llms_app import run

# launch the ensemble project and run each specified LLM agent.
run()
# Out:
# Home path: /project/DPDS/Xiao_lab/s221963/2025_LLMsAgents/example_project_small
# Start at: 2025-08-22 03:34:31.151464
# LLM agent app home path: /project/DPDS/Xiao_lab/s221963/2025_LLMsAgents/example_project_small/gpt-4.1-mini_P07
# Model: gpt-4.1-mini
# Dataset: lung
# Start at: 2025-08-22 03:34:31.246612
# 11:  TCGA-38-4630
# End at: 2025-08-22 03:36:18.073180
# Elapsed time: 1.780443 minutes (106.826567 seconds).
#
# Failed requests: []
# Failed json loading: 0
# []
# Input Tokens: 16708
# Output Tokens: 6798
# Total Tokens: 23506
# Model gpt-4.1-mini is not in GPT family, and is free:-)
#
# The output csv file saved to /project/DPDS/Xiao_lab/s221963/2025_LLMsAgents/example_project_small/gpt-4.1-mini_P07/data/lung_gpt-4.1-mini_P07.csv.
# Computing with gpt-4.1-mini for lung succeed.
#
# LLM agent app home path: /project/DPDS/Xiao_lab/s221963/2025_LLMsAgents/example_project_small/gpt-4o-mini_P07
# Model: gpt-4o-mini
# Dataset: lung
# Start at: 2025-08-22 03:36:18.116353
# ...
